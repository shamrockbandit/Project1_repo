# %%
import pandas as pd
import numpy as np

# %%
#  Notebook exeercising API
freedom_csv_path = "data/indexfreedom.csv"
#happy_csv_path = "data/TBD"

# %%
# READ freedom.csv

freedom_df = pd.read_csv(freedom_csv_path, encoding="utf-8")
freedom_df
# Out:
#       year ISO_code    countries                         region  \
# 0     2016      ALB      Albania                 Eastern Europe
# 1     2016      DZA      Algeria     Middle East & North Africa
# 2     2016      AGO       Angola             Sub-Saharan Africa
# 3     2016      ARG    Argentina  Latin America & the Caribbean
# 4     2016      ARM      Armenia        Caucasus & Central Asia
# ...    ...      ...          ...                            ...
# 1453  2008      VEN    Venezuela  Latin America & the Caribbean
# 1454  2008      VNM      Vietnam                     South Asia
# 1455  2008      YEM  Yemen, Rep.     Middle East & North Africa
# 1456  2008      ZMB       Zambia             Sub-Saharan Africa
# 1457  2008      ZWE     Zimbabwe             Sub-Saharan Africa
#
#       pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  \
# 0              6.661503      4.547244         4.666508  5.291752
# ...

# %%
# drop rows for 2008-2015 
# other_years = freedom_df[ (freedom_df['year'] < 2016) ].index

# Delete these row indexes from dataFrame
# only_2016_df= freedom_df.drop(other_years , inplace=True)


# freedom_df

# %%
money_growth_df = freedom_df[['countries','ef_money_growth','hf_score']]
money_growth_df
# Out:
#         countries  ef_money_growth  hf_score
# 0         Albania         8.986454  7.568140
# 1         Algeria         6.955962  5.135886
# 2          Angola         9.385679  5.640662
# 3       Argentina         5.233264  6.469848
# 4         Armenia         9.078264  7.241402
# ...           ...              ...       ...
# 1453    Venezuela         6.056618  5.257879
# 1454      Vietnam         8.095573  6.420206
# 1455  Yemen, Rep.              NaN       NaN
# 1456       Zambia         7.940899  6.647724
# 1457     Zimbabwe         0.000000  4.935571
#
# [1458 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
# first turn columns into lists
money_growth = money_growth_df["ef_money_growth"].values
hf_score = money_growth_df["hf_score"].values
countries = money_growth_df["countries"].values

# %%
# create plot
fig, ax = plt.subplots()

ax.scatter(money_growth, hf_score)

plt.title("Money Growth v Human Freedom Score")
plt.xlabel("Money Growth")
plt.ylabel("Human Freedom Score")
# Out:
# Text(0, 0.5, 'Human Freedom Score')

# %%
# independent t-test
import scipy.stats as stats

# %%
mask = ~np.isnan(money_growth) & ~np.isnan(hf_score)

stats.ttest_ind(money_growth[mask], hf_score[mask], equal_var=False)
# Out:
# Ttest_indResult(statistic=40.7528528183871, pvalue=2.6422597889857593e-284)

# %%
# pvalue is low so the null must go
# Out:
#   File "<ipython-input-21-e92d53401e38>", line 1
#     pvalue is low so the null must go
#                    ^
# SyntaxError: invalid syntax
