# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
#  Notebook exeercising API
freedom_csv_path = "data/indexfreedom.csv"
#happy_csv_path = "data/TBD"

# %%
# READ freedom.csv

freedom_df = pd.read_csv(freedom_csv_path, encoding="utf-8")
freedom_df
# Out:
#       year ISO_code    countries                         region  \
# 0     2016      ALB      Albania                 Eastern Europe
# 1     2016      DZA      Algeria     Middle East & North Africa
# 2     2016      AGO       Angola             Sub-Saharan Africa
# 3     2016      ARG    Argentina  Latin America & the Caribbean
# 4     2016      ARM      Armenia        Caucasus & Central Asia
# ...    ...      ...          ...                            ...
# 1453  2008      VEN    Venezuela  Latin America & the Caribbean
# 1454  2008      VNM      Vietnam                     South Asia
# 1455  2008      YEM  Yemen, Rep.     Middle East & North Africa
# 1456  2008      ZMB       Zambia             Sub-Saharan Africa
# 1457  2008      ZWE     Zimbabwe             Sub-Saharan Africa
#
#       pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  \
# 0              6.661503      4.547244         4.666508  5.291752
# 1                   NaN           NaN              NaN  3.819566
# 2                   NaN           NaN              NaN  3.451814
# 3              7.098483      5.791960         4.343930  5.744791
# 4                   NaN           NaN              NaN  5.003205
# ...                 ...           ...              ...       ...
# 1453           3.000000      3.781688         2.369239  3.100000
# 1454           6.666667      4.349101         5.694847  5.600000
# 1455                NaN           NaN              NaN       NaN
# 1456           4.800000      4.578003         3.688652  4.400000
# 1457           2.700000      3.991582         4.327660  3.700000
#
#       pf_ss_homicide  pf_ss_disappearances_disap  ...  \
# 0           8.920429                        10.0  ...
# 1           9.456254                        10.0  ...
# 2           8.060260                         5.0  ...
# 3           7.622974                        10.0  ...
# 4           8.808750                        10.0  ...
# ...              ...                         ...  ...
# 1453        0.000000                        10.0  ...
# 1454        9.496239                         5.0  ...
# 1455             NaN                         NaN  ...
# 1456        7.878084                        10.0  ...
# 1457        7.981019                         0.0  ...
#
#       ef_regulation_business_bribes  ef_regulation_business_licensing  \
# 0                          4.050196                          7.324582
# 1                          3.765515                          8.523503
# 2                          1.945540                          8.096776
# 3                          3.260044                          5.253411
# 4                          4.575152                          9.319612
# ...                             ...                               ...
# 1453                       2.784695                          4.578318
# 1454                       3.626593                          7.306074
# 1455                            NaN                               NaN
# 1456                       4.585391                          5.124436
# 1457                       4.423866                          0.000000
#
#       ef_regulation_business_compliance  ef_regulation_business  \
# 0                              7.074366                6.705863
# 1                              7.029528                5.676956
# 2                              6.782923                4.930271
# 3                              6.508295                5.535831
# 4                              6.491481                6.797530
# ...                                 ...                     ...
# 1453                           0.315142                2.864160
# 1454                           0.000000                4.574683
# 1455                                NaN                     NaN
# 1456                           8.520369                6.681524
# 1457                           6.973482                3.369110
#
#       ef_regulation  ef_score  ef_rank  hf_score  hf_rank  hf_quartile
# 0          6.906901      7.54     34.0  7.568140     48.0          2.0
# 1          5.268992      4.99    159.0  5.135886    155.0          4.0
# 2          5.518500      5.17    155.0  5.640662    142.0          4.0
# 3          5.369019      4.84    160.0  6.469848    107.0          3.0
# 4          7.378069      7.57     29.0  7.241402     57.0          2.0
# ...             ...       ...      ...       ...      ...          ...
# 1453       4.666936      4.22    140.0  5.257879    136.0          4.0
# 1454       6.307577      6.19    103.0  6.420206    106.0          3.0
# 1455            NaN       NaN      NaN       NaN      NaN          NaN
# 1456       6.722175      7.15     57.0  6.647724     95.0          3.0
# 1457       4.488892      4.55    138.0  4.935571    140.0          4.0
#
# [1458 rows x 123 columns]

# %%
# index is just range from 0 to 1457
# could make it ISO code or country if needed in merged df
freedom_df.index
# Out:
# RangeIndex(start=0, stop=1458, step=1)

# %%
# columns are a bunch of data I don't understand yet
freedom_df.columns
# Out:
# Index(['year', 'ISO_code', 'countries', 'region', 'pf_rol_procedural',
#        'pf_rol_civil', 'pf_rol_criminal', 'pf_rol', 'pf_ss_homicide',
#        'pf_ss_disappearances_disap',
#        ...
#        'ef_regulation_business_bribes', 'ef_regulation_business_licensing',
#        'ef_regulation_business_compliance', 'ef_regulation_business',
#        'ef_regulation', 'ef_score', 'ef_rank', 'hf_score', 'hf_rank',
#        'hf_quartile'],
#       dtype='object', length=123)

# %%
# refresh on selecting data using [], .loc[], and .iloc[]
# https://medium.com/dunder-data/selecting-subsets-of-data-in-pandas-6fcd0170be9c

# %%
# Freedom Data is binned by region
freedom_df['region'].values
# Out:
# array(['Eastern Europe', 'Middle East & North Africa',
#        'Sub-Saharan Africa', ..., 'Middle East & North Africa',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa'], dtype=object)

# %%
''# copy the freedom_df and make 'coutnries the index
freedom_country_df = freedom_df.copy()
freedom_country_df.set_index(['countries'], inplace=True)
freedom_country_df
# Out:
#              year ISO_code                         region  pf_rol_procedural  \
# countries
# Albania      2016      ALB                 Eastern Europe           6.661503
# Algeria      2016      DZA     Middle East & North Africa                NaN
# Angola       2016      AGO             Sub-Saharan Africa                NaN
# Argentina    2016      ARG  Latin America & the Caribbean           7.098483
# Armenia      2016      ARM        Caucasus & Central Asia                NaN
# ...           ...      ...                            ...                ...
# Venezuela    2008      VEN  Latin America & the Caribbean           3.000000
# Vietnam      2008      VNM                     South Asia           6.666667
# Yemen, Rep.  2008      YEM     Middle East & North Africa                NaN
# Zambia       2008      ZMB             Sub-Saharan Africa           4.800000
# Zimbabwe     2008      ZWE             Sub-Saharan Africa           2.700000
#
#              pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# countries
# Albania          4.547244         4.666508  5.291752        8.920429
# Algeria               NaN              NaN  3.819566        9.456254
# Angola                NaN              NaN  3.451814        8.060260
# Argentina        5.791960         4.343930  5.744791        7.622974
# Armenia               NaN              NaN  5.003205        8.808750
# ...                   ...              ...       ...             ...
# Venezuela        3.781688         2.369239  3.100000        0.000000
# Vietnam          4.349101         5.694847  5.600000        9.496239
# Yemen, Rep.           NaN              NaN       NaN             NaN
# Zambia           4.578003         3.688652  4.400000        7.878084
# Zimbabwe         3.991582         4.327660  3.700000        7.981019
#
#              pf_ss_disappearances_disap  pf_ss_disappearances_violent  ...  \
# countries                                                              ...
# Albania                            10.0                      10.00000  ...
# Algeria                            10.0                       9.29403  ...
# Angola                              5.0                      10.00000  ...
# Argentina                          10.0                      10.00000  ...
# Armenia                            10.0                      10.00000  ...
# ...                                 ...                           ...  ...
# Venezuela                          10.0                      10.00000  ...
# Vietnam                             5.0                      10.00000  ...
# Yemen, Rep.                         NaN                           NaN  ...
# Zambia                             10.0                      10.00000  ...
# Zimbabwe                            0.0                      10.00000  ...
#
#              ef_regulation_business_bribes  ef_regulation_business_licensing  \
# countries
# Albania                           4.050196                          7.324582
# Algeria                           3.765515                          8.523503
# Angola                            1.945540                          8.096776
# Argentina                         3.260044                          5.253411
# Armenia                           4.575152                          9.319612
# ...                                    ...                               ...
# Venezuela                         2.784695                          4.578318
# Vietnam                           3.626593                          7.306074
# Yemen, Rep.                            NaN                               NaN
# Zambia                            4.585391                          5.124436
# Zimbabwe                          4.423866                          0.000000
#
#              ef_regulation_business_compliance  ef_regulation_business  \
# countries
# Albania                               7.074366                6.705863
# Algeria                               7.029528                5.676956
# Angola                                6.782923                4.930271
# Argentina                             6.508295                5.535831
# Armenia                               6.491481                6.797530
# ...                                        ...                     ...
# Venezuela                             0.315142                2.864160
# Vietnam                               0.000000                4.574683
# Yemen, Rep.                                NaN                     NaN
# Zambia                                8.520369                6.681524
# Zimbabwe                              6.973482                3.369110
#
#              ef_regulation  ef_score  ef_rank  hf_score  hf_rank  hf_quartile
# countries
# Albania           6.906901      7.54     34.0  7.568140     48.0          2.0
# Algeria           5.268992      4.99    159.0  5.135886    155.0          4.0
# Angola            5.518500      5.17    155.0  5.640662    142.0          4.0
# Argentina         5.369019      4.84    160.0  6.469848    107.0          3.0
# Armenia           7.378069      7.57     29.0  7.241402     57.0          2.0
# ...                    ...       ...      ...       ...      ...          ...
# Venezuela         4.666936      4.22    140.0  5.257879    136.0          4.0
# Vietnam           6.307577      6.19    103.0  6.420206    106.0          3.0
# Yemen, Rep.            NaN       NaN      NaN       NaN      NaN          NaN
# Zambia            6.722175      7.15     57.0  6.647724     95.0          3.0
# Zimbabwe          4.488892      4.55    138.0  4.935571    140.0          4.0
#
# [1458 rows x 122 columns]

# %%
# looking at a few data columns.  some NAN's 
freedom_country_df.iloc[:, 2 : -1]

# some countries have no data (all NaN)
# others have some data (only a few columns with NaN)
# Out:
#                                     region  pf_rol_procedural  pf_rol_civil  \
# countries
# Albania                     Eastern Europe           6.661503      4.547244
# Algeria         Middle East & North Africa                NaN           NaN
# Angola                  Sub-Saharan Africa                NaN           NaN
# Argentina    Latin America & the Caribbean           7.098483      5.791960
# Armenia            Caucasus & Central Asia                NaN           NaN
# ...                                    ...                ...           ...
# Venezuela    Latin America & the Caribbean           3.000000      3.781688
# Vietnam                         South Asia           6.666667      4.349101
# Yemen, Rep.     Middle East & North Africa                NaN           NaN
# Zambia                  Sub-Saharan Africa           4.800000      4.578003
# Zimbabwe                Sub-Saharan Africa           2.700000      3.991582
#
#              pf_rol_criminal    pf_rol  pf_ss_homicide  \
# countries
# Albania             4.666508  5.291752        8.920429
# Algeria                  NaN  3.819566        9.456254
# Angola                   NaN  3.451814        8.060260
# Argentina           4.343930  5.744791        7.622974
# Armenia                  NaN  5.003205        8.808750
# ...                      ...       ...             ...
# Venezuela           2.369239  3.100000        0.000000
# Vietnam             5.694847  5.600000        9.496239
# Yemen, Rep.              NaN       NaN             NaN
# Zambia              3.688652  4.400000        7.878084
# Zimbabwe            4.327660  3.700000        7.981019
#
#              pf_ss_disappearances_disap  pf_ss_disappearances_violent  \
# countries
# Albania                            10.0                      10.00000
# Algeria                            10.0                       9.29403
# Angola                              5.0                      10.00000
# Argentina                          10.0                      10.00000
# Armenia                            10.0                      10.00000
# ...                                 ...                           ...
# Venezuela                          10.0                      10.00000
# Vietnam                             5.0                      10.00000
# Yemen, Rep.                         NaN                           NaN
# Zambia                             10.0                      10.00000
# Zimbabwe                            0.0                      10.00000
#
#              pf_ss_disappearances_organized  pf_ss_disappearances_fatalities  \
# countries
# Albania                               10.00                        10.000000
# Algeria                                5.00                         9.926119
# Angola                                 7.50                        10.000000
# Argentina                              7.50                        10.000000
# Armenia                                7.50                         9.316196
# ...                                     ...                              ...
# Venezuela                             10.00                         9.988155
# Vietnam                               10.00                        10.000000
# Yemen, Rep.                             NaN                              NaN
# Zambia                                10.00                        10.000000
# Zimbabwe                               1.25                         9.827906
#
#              ...  ef_regulation_business_start  ef_regulation_business_bribes  \
# countries    ...
# Albania      ...                      9.713864                       4.050196
# Algeria      ...                      9.243070                       3.765515
# Angola       ...                      8.664627                       1.945540
# Argentina    ...                      9.122357                       3.260044
# Armenia      ...                      9.846472                       4.575152
# ...          ...                           ...                            ...
# Venezuela    ...                      6.414559                       2.784695
# Vietnam      ...                      8.259464                       3.626593
# Yemen, Rep.  ...                           NaN                            NaN
# Zambia       ...                      9.121114                       4.585391
# Zimbabwe     ...                      3.593080                       4.423866
#
#              ef_regulation_business_licensing  \
# countries
# Albania                              7.324582
# Algeria                              8.523503
# Angola                               8.096776
# Argentina                            5.253411
# Armenia                              9.319612
# ...                                       ...
# Venezuela                            4.578318
# Vietnam                              7.306074
# Yemen, Rep.                               NaN
# Zambia                               5.124436
# Zimbabwe                             0.000000
#
#              ef_regulation_business_compliance  ef_regulation_business  \
# countries
# Albania                               7.074366                6.705863
# Algeria                               7.029528                5.676956
# Angola                                6.782923                4.930271
# Argentina                             6.508295                5.535831
# Armenia                               6.491481                6.797530
# ...                                        ...                     ...
# Venezuela                             0.315142                2.864160
# Vietnam                               0.000000                4.574683
# Yemen, Rep.                                NaN                     NaN
# Zambia                                8.520369                6.681524
# Zimbabwe                              6.973482                3.369110
#
#              ef_regulation  ef_score  ef_rank  hf_score  hf_rank
# countries
# Albania           6.906901      7.54     34.0  7.568140     48.0
# Algeria           5.268992      4.99    159.0  5.135886    155.0
# Angola            5.518500      5.17    155.0  5.640662    142.0
# Argentina         5.369019      4.84    160.0  6.469848    107.0
# Armenia           7.378069      7.57     29.0  7.241402     57.0
# ...                    ...       ...      ...       ...      ...
# Venezuela         4.666936      4.22    140.0  5.257879    136.0
# Vietnam           6.307577      6.19    103.0  6.420206    106.0
# Yemen, Rep.            NaN       NaN      NaN       NaN      NaN
# Zambia            6.722175      7.15     57.0  6.647724     95.0
# Zimbabwe          4.488892      4.55    138.0  4.935571    140.0
#
# [1458 rows x 119 columns]

# %%
freedom_country_df.shape
# Out:
# (1458, 122)

# %%
# droping all NaN's loses the entire data set.
# may need to select which columns we care about data existing 
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
#freedom_noNan_df = freedom_country_df.dropna()

print(f"Original data shape: {freedom_country_df.shape}")
print(f"No NaN shape: {freedom_country_df.dropna().shape}")
# Out:
# Original data shape: (1458, 122)
# No NaN shape: (0, 122)

# %%
# Example select a column we care about having data and drop NaN rows from that 
freedom_clean_df = freedom_country_df.dropna(subset=['ef_score'])
print(f"df shape after selected dropna: {freedom_clean_df.shape} ")

freedom_clean_df
# Out:
# df shape after selected dropna: (1378, 122)
#            year ISO_code                         region  pf_rol_procedural  \
# countries
# Albania    2016      ALB                 Eastern Europe           6.661503
# Algeria    2016      DZA     Middle East & North Africa                NaN
# Angola     2016      AGO             Sub-Saharan Africa                NaN
# Argentina  2016      ARG  Latin America & the Caribbean           7.098483
# Armenia    2016      ARM        Caucasus & Central Asia                NaN
# ...         ...      ...                            ...                ...
# Uruguay    2008      URY  Latin America & the Caribbean           7.033333
# Venezuela  2008      VEN  Latin America & the Caribbean           3.000000
# Vietnam    2008      VNM                     South Asia           6.666667
# Zambia     2008      ZMB             Sub-Saharan Africa           4.800000
# Zimbabwe   2008      ZWE             Sub-Saharan Africa           2.700000
#
#            pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# countries
# Albania        4.547244         4.666508  5.291752        8.920429
# Algeria             NaN              NaN  3.819566        9.456254
# Angola              NaN              NaN  3.451814        8.060260
# Argentina      5.791960         4.343930  5.744791        7.622974
# Armenia             NaN              NaN  5.003205        8.808750
# ...                 ...              ...       ...             ...
# Uruguay        7.140849         5.035222  6.400000        7.361843
# Venezuela      3.781688         2.369239  3.100000        0.000000
# Vietnam        4.349101         5.694847  5.600000        9.496239
# Zambia         4.578003         3.688652  4.400000        7.878084
# Zimbabwe       3.991582         4.327660  3.700000        7.981019
#
#            pf_ss_disappearances_disap  pf_ss_disappearances_violent  ...  \
# countries                                                            ...
# Albania                          10.0                      10.00000  ...
# Algeria                          10.0                       9.29403  ...
# Angola                            5.0                      10.00000  ...
# Argentina                        10.0                      10.00000  ...
# Armenia                          10.0                      10.00000  ...
# ...                               ...                           ...  ...
# Uruguay                          10.0                      10.00000  ...
# Venezuela                        10.0                      10.00000  ...
# Vietnam                           5.0                      10.00000  ...
# Zambia                           10.0                      10.00000  ...
# Zimbabwe                          0.0                      10.00000  ...
#
#            ef_regulation_business_bribes  ef_regulation_business_licensing  \
# countries
# Albania                         4.050196                          7.324582
# Algeria                         3.765515                          8.523503
# Angola                          1.945540                          8.096776
# Argentina                       3.260044                          5.253411
# Armenia                         4.575152                          9.319612
# ...                                  ...                               ...
# Uruguay                         7.112031                          6.944885
# Venezuela                       2.784695                          4.578318
# Vietnam                         3.626593                          7.306074
# Zambia                          4.585391                          5.124436
# Zimbabwe                        4.423866                          0.000000
#
#            ef_regulation_business_compliance  ef_regulation_business  \
# countries
# Albania                             7.074366                6.705863
# Algeria                             7.029528                5.676956
# Angola                              6.782923                4.930271
# Argentina                           6.508295                5.535831
# Armenia                             6.491481                6.797530
# ...                                      ...                     ...
# Uruguay                             6.233666                5.748001
# Venezuela                           0.315142                2.864160
# Vietnam                             0.000000                4.574683
# Zambia                              8.520369                6.681524
# Zimbabwe                            6.973482                3.369110
#
#            ef_regulation  ef_score  ef_rank  hf_score  hf_rank  hf_quartile
# countries
# Albania         6.906901      7.54     34.0  7.568140     48.0          2.0
# Algeria         5.268992      4.99    159.0  5.135886    155.0          4.0
# Angola          5.518500      5.17    155.0  5.640662    142.0          4.0
# Argentina       5.369019      4.84    160.0  6.469848    107.0          3.0
# Armenia         7.378069      7.57     29.0  7.241402     57.0          2.0
# ...                  ...       ...      ...       ...      ...          ...
# Uruguay         6.162140      7.12     58.0  7.947847     37.0          2.0
# Venezuela       4.666936      4.22    140.0  5.257879    136.0          4.0
# Vietnam         6.307577      6.19    103.0  6.420206    106.0          3.0
# Zambia          6.722175      7.15     57.0  6.647724     95.0          3.0
# Zimbabwe        4.488892      4.55    138.0  4.935571    140.0          4.0
#
# [1378 rows x 122 columns]
