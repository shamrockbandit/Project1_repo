# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
#  Notebook exeercising API
freedom_csv_path = "data/indexfreedom.csv"
#happy_csv_path = "data/TBD"

# %%
# READ freedom.csv

freedom_df = pd.read_csv(freedom_csv_path, encoding="utf-8")
freedom_df
# Out:
#       year ISO_code    countries                         region  \
# 0     2016      ALB      Albania                 Eastern Europe
# 1     2016      DZA      Algeria     Middle East & North Africa
# 2     2016      AGO       Angola             Sub-Saharan Africa
# 3     2016      ARG    Argentina  Latin America & the Caribbean
# 4     2016      ARM      Armenia        Caucasus & Central Asia
# ...    ...      ...          ...                            ...
# 1453  2008      VEN    Venezuela  Latin America & the Caribbean
# 1454  2008      VNM      Vietnam                     South Asia
# 1455  2008      YEM  Yemen, Rep.     Middle East & North Africa
# 1456  2008      ZMB       Zambia             Sub-Saharan Africa
# 1457  2008      ZWE     Zimbabwe             Sub-Saharan Africa
#
#       pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  \
# 0              6.661503      4.547244         4.666508  5.291752
# ...

# %%
# drop rows for 2008-2015 
other_years = freedom_df[ (freedom_df['year'] < 2016) ].index

# Delete these row indexes from dataFrame
only_2016_df= freedom_df.drop(other_years , inplace=True)


freedom_df
# Out:
#      year ISO_code    countries                         region  \
# 0    2016      ALB      Albania                 Eastern Europe
# 1    2016      DZA      Algeria     Middle East & North Africa
# 2    2016      AGO       Angola             Sub-Saharan Africa
# 3    2016      ARG    Argentina  Latin America & the Caribbean
# 4    2016      ARM      Armenia        Caucasus & Central Asia
# ..    ...      ...          ...                            ...
# 157  2016      VEN    Venezuela  Latin America & the Caribbean
# 158  2016      VNM      Vietnam                     South Asia
# 159  2016      YEM  Yemen, Rep.     Middle East & North Africa
# 160  2016      ZMB       Zambia             Sub-Saharan Africa
# 161  2016      ZWE     Zimbabwe             Sub-Saharan Africa
#
#      pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  \
# 0             6.661503      4.547244         4.666508  5.291752
# 1                  NaN           NaN              NaN  3.819566
# ...

# %%
# keep only the ef_score and pf_score
scores_df= freedom_df[['countries','hf_score','pf_score']]
scores_df
# Out:
#        countries  hf_score  pf_score
# 0        Albania  7.568140  7.596281
# 1        Algeria  5.135886  5.281772
# 2         Angola  5.640662  6.111324
# 3      Argentina  6.469848  8.099696
# 4        Armenia  7.241402  6.912804
# ..           ...       ...       ...
# 157    Venezuela  4.200724  5.521449
# 158      Vietnam  6.194004  5.968008
# 159  Yemen, Rep.  4.253278  2.166555
# 160       Zambia  6.308849  6.007699
# 161     Zimbabwe  5.615363  5.170726
#
# [162 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
# plot
# first turn columns into lists
pf_internet_score = scores_df["pf_score"].values
hf_score = scores_df["hf_score"].values
countries = scores_df["countries"].values

# %%
# create plot
fig, ax = plt.subplots()
ax.scatter(pf_score, hf_score)

for i, txt in enumerate(countries):
    ax.annotate(txt, (pf_score[i], hf_score[i]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-3342c950817f> in <module>
#       1 # create plot
#       2 fig, ax = plt.subplots()
# ----> 3 ax.scatter(pf_score, hf_score)
#       4
#       5 for i, txt in enumerate(countries):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4442         y = np.ma.ravel(y)
#    4443         if x.size != y.size:
# ...

# %%
# with out labels bc idk how to clean it up
fig, ax = plt.subplots()
ax.scatter(pf_score, hf_score)
plt.title("Personal Freedom expression internet vs Human Freedom")
plt.xlabel("Personal Freedom expression internet")
plt.ylabel("Human Freedom")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-9da68f1c24dd> in <module>
#       1 # with out labels bc idk how to clean it up
#       2 fig, ax = plt.subplots()
# ----> 3 ax.scatter(pf_score, hf_score)
#       4 plt.title("Personal Freedom expression internet vs Human Freedom")
#       5 plt.xlabel("Personal Freedom expression internet")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
import scipy.stats as stats

# %%
# give or take a few outliers it seems to be that higher personal freedom correlates to higher ecoonomic freedom
# independent t-test
stats.ttest_ind(pf_score, hf_score, equal_var=False)
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
# pvalue is greater than .05 so accept the null?
